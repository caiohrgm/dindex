# %%
import pandas as pd

df = pd.read_csv("../../public/data/digimons.csv")

# df = df.drop(["id"], axis=1)

df['name'] = df['name'].str.replace('_', ' ')


display(df.head(20))
# Out:
#     id                         name  \
# 0    1                    Abbadomon
# 1    2               Abbadomon Core
# 2    3                  Achillesmon
# 3    4                 Aegiochusmon
# 4    5            Aegiochusmon Blue
# 5    6            Aegiochusmon Dark
# 6    7           Aegiochusmon Green
# 7    8            Aegiochusmon Holy
# 8    9                     Aegiomon
# 9   10                  Aegisdramon
# 10  11                 Aequcedramon
# 11  12                AeroVeedramon
# 12  13                       Agumon
# 13  14          Agumon (2006 anime)
# 14  15  Agumon (Black) (2006 anime)
# 15  16     Agumon (Bond of Bravery)
# 16  17          Agumon (Burst Mode)
# 17  18                Agumon Expert
# 18  19                     Agumon X
# 19  20                     Agunimon
#
#                                                 image       level  type  \
# 0   https://static.wikia.nocookie.net/digimon/imag...        Mega   NaN
# ...
